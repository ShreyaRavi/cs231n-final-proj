# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

cf_matrix_blur_only = np.array([[213,  77,   6,  12,   5,  28,   1,   4,  33,   8],
       [ 37, 219,   3,  29,  22,  34,  24,   2,   7,  13],
       [  7,  25, 248,   1,  26,   7,  36,   0,  68,  10],
       [ 41,  35,   8, 304,   4,   8,   0,   0,  22,   2],
       [ 26,  44,  11,  22, 201,  30,  17,   0,  78,   0],
       [ 60,  56,  15,   3,  11, 220,   9,   7,  21,  36],
       [  5,  26,  37,   9,  15,   4, 264,   0,  77,   0],
       [ 17,   9,  15,  13,  13,   6,   7, 248,  14,  25],
       [ 13,  43,  42,   5,  47,   3,  51,  16, 168,   0],
       [135,  83,   0,  15,   5,  32,   0,   2,   5, 115]])

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_blur_only/np.sum(cf_matrix_blur_only, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')

# %%
cf_matrix_baseline = np.array([
       [207,  38,   1,   2,  16,  28,   1,   1,  70,  23],
       [ 15, 163,   1,  12,  43,  36,  12,   8,  29,  71],
       [  1,   9, 239,   0,  14,  28,   8,   0, 129,   0],
       [ 41,  11,   0, 289,  46,   1,   0,   0,  21,  15],
       [ 20,   2,   4,   2, 195,  20,   9,   0, 170,   7],
       [ 14,  12,   1,   0,  17, 265,   3,  23,  56,  47],
       [  1,   6,  39,   3,   4,  18, 262,   1, 103,   0],
       [  4,   0,   6,   2,   6,  30,   1, 243,  21,  54],
       [  5,  16,  38,   2,  50,   7,  28,  22, 219,   1],
       [ 64,  55,   0,   3,   9,  21,   0,  15,  21, 204]])

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_baseline/np.sum(cf_matrix_baseline, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')
# the actual baseline

# %%
cf_matrix_baseline = np.array([
       [357,  2,   1,   11,  0,  2,   0, 0,  2,  12],
       [ 18, 357,   1,  2,  0,  2,  2,   0,  0,  8],
       [  1,   3, 413,   0,  0,  1,  2,  0,   6, 129],
       [ 2, 0, 1, 417, 4, 0, 0, 0, 0, 0],
       [ 3, 0, 0, 1, 423, 1, 1, 0, 0, 0],
       [ 17, 0, 0, 0, 0, 411, 0, 0, 0, 10],
       [  0, 3, 4, 0, 3, 1, 406, 1, 19, 0],
       [  2, 0, 2, 0, 0, 0, 0, 363, 0, 0],
       [  7, 4, 19, 1, 3, 0, 44, 9, 298, 3],
       [ 28, 1, 0, 0, 1, 0, 1, 0, 0, 361]])

# %%
# classical augmentation only
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_baseline/np.sum(cf_matrix_baseline, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')

# %%
cf_matrix_skin_aug = np.array([
       [138,  66,   3,   7,  8,  2,  6,  2,  7,  46],
       [ 57, 206,   2,  5,  10, 20, 35,  2,  28, 25],
       [ 0, 5, 245, 0, 1, 6, 10, 0, 160, 1],
       [ 10, 21, 0, 305, 42, 15, 6, 0, 0, 25],
       [ 6, 9, 41, 3, 254, 4, 13, 0, 93, 6],
       [ 21, 36, 0, 5, 6, 332, 4, 4, 12, 18],
       [ 3, 46, 31, 1, 5, 0, 221, 0, 130, 0],
       [ 10, 8, 0, 4, 5, 25, 3, 244, 30, 38],
       [ 3, 7, 81, 0, 6, 1, 78, 19, 191, 2],
       [ 118, 76, 1, 5, 2, 29, 1, 4, 3, 153]])

# %%
# skin seg aug only
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_skin_aug/np.sum(cf_matrix_skin_aug, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')

# %%
cf_matrix_ensemble = np.array([
       [169, 24, 11, 20, 6, 87, 2, 10, 45, 13],
       [12, 169, 7, 29, 10, 71, 19, 12, 41, 20],
       [ 0, 1, 371, 0, 0, 0, 6, 0, 50, 0],
       [ 1, 8, 1, 385, 9, 13, 0, 1, 4, 2],
       [ 7, 1, 52, 6, 292, 14, 4, 0, 47, 6],
       [ 3, 18, 1, 5, 1, 368, 0, 28, 11, 3],
       [ 0, 2, 178, 6, 9, 1, 185, 1, 55, 0],
       [ 2, 1, 4, 7, 3, 9, 2, 322, 2, 15],
       [ 5, 3, 127, 0, 4, 1, 32, 28, 187, 1],
       [ 87, 38, 1, 24, 9, 81, 0, 17, 11, 124]])

# %%
# full ensemble
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_ensemble/np.sum(cf_matrix_ensemble, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')

# %%
cf_matrix_classical_aug = np.array([
       [229, 23, 0, 4, 3, 45, 4, 0, 18, 61],
       [21, 187, 0, 44, 0, 45, 18, 0, 16, 59],
       [ 2, 10, 192, 0, 3, 8, 60, 1, 136, 16],
       [ 19, 21, 0, 345, 1, 30, 1, 0, 1, 6],
       [ 33, 10, 2, 8, 298, 35, 28, 0, 10, 5],
       [ 13, 28, 0, 0, 0, 379, 0, 2, 3, 13],
       [ 5, 18, 28, 7, 8, 1, 264, 1, 104, 1],
       [ 1, 2, 2, 5, 0, 9, 1, 283, 10, 54],
       [ 9, 16, 15, 2, 27, 6, 67, 21, 210, 15],
       [ 118, 41, 0, 3, 0, 35, 0, 1, 0, 194]])

# %%
# classical aug
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_classical_aug/np.sum(cf_matrix_classical_aug, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')

# %%
cf_matrix_blur_aug = np.array([
       [238, 58, 0, 5, 0, 19, 1, 0, 50, 16],
       [47, 231, 0, 12, 17, 19, 24, 0, 8, 32],
       [14, 34, 236, 1, 17, 7, 71, 0, 47, 1],
       [ 50, 44, 0, 313, 6, 0, 0, 0, 3, 8],
       [ 46, 43, 2, 0, 289, 6, 15, 0, 26, 2],
       [ 77, 85, 0, 0, 6, 227, 7, 5, 8, 23],
       [ 12, 34, 31, 2, 16, 4, 314, 0, 24, 0],
       [ 4, 14, 6, 3, 8, 1, 7, 241, 13, 70],
       [ 14, 43, 41, 1, 41, 2, 59, 13, 173, 1],
       [ 130, 74, 0, 12, 2, 11, 0, 7, 1, 155]])

# %%
# blur aug
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_blur_aug/np.sum(cf_matrix_blur_aug, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')

# %%
cf_matrix_skin_aug = np.array([
       [138, 66, 3, 7, 8, 104, 6, 2, 7, 46],
       [57, 206, 2, 5, 10, 20, 35, 2, 28, 25],
       [0, 5, 245, 0, 1, 6, 10, 0, 160, 1],
       [ 10, 21, 0, 305, 42, 15, 6, 0, 0, 25],
       [ 6, 9, 41, 3, 254, 4, 13, 0, 93, 6],
       [ 21, 36, 0, 5, 6, 332, 4, 4, 12, 18],
       [ 3, 46, 31, 1, 5, 0, 221, 0, 130, 0],
       [ 10, 8, 0, 4, 5, 25, 3, 244, 30, 38],
       [ 3, 7, 81, 0, 6, 1, 78, 19, 191, 2],
       [ 118, 76, 1, 5, 2, 29, 1, 4, 3, 153]])

# %%
# skin seg aug aug
plt.subplots(figsize=(10,8))
sns.heatmap(cf_matrix_skin_aug/np.sum(cf_matrix_skin_aug, axis=0), annot=True, 
            fmt='.2%', cmap='Blues')
